# %%
import os
import pandas as pd
import numpy as np

# %%
np.random.seed(50)

# %%
from datetime import date
from matplotlib import pyplot as plt

# %%
from sklearn.preprocessing import MinMaxScaler, StandardScaler
from keras.models import Sequential, Model
from keras.models import Model
from keras.layers import Dense, Dropout, LSTM, Input, Activation, concatenate

# %%
import tensorflow as tf
tf.random.set_seed(40)

# %%
import matplotlib.pyplot as plt
import datetime as dt 
import urllib.request, json

# %%
df = pd.read_csv('https://raw.githubusercontent.com/cybercat37794/Stock-Price-Prediction/main/BXPH%20Stock%20Price/BXPH%20Historical%20Data%20New.csv')

# %%
print(df)
# Out:
#               Date  Close   Open   High    Low     Vol. Change %
# 0     Apr 28, 2022  165.7  167.4  167.4  164.8  275.14K   -1.02%
# 1     Apr 27, 2022  167.4  168.7  168.7  166.4  277.05K    0.78%
# 2     Apr 26, 2022  166.1  166.0  167.7  165.8  796.68K    0.00%
# 3     Apr 25, 2022  166.1  166.9  167.8  165.9  137.41K   -1.07%
# 4     Apr 24, 2022  167.9  167.9  169.2  167.0  380.19K    0.60%
# ...            ...    ...    ...    ...    ...      ...      ...
# 1824  Aug 18, 2014   39.0   39.0   40.0   39.0    1.03M    0.00%
# 1825  Aug 14, 2014   39.0   39.0   39.0   39.0  797.00K    0.00%
# 1826  Aug 13, 2014   39.0   39.0   39.0   38.0  285.77K    2.63%
# 1827  Aug 12, 2014   38.0   39.0   40.0   38.0  587.19K   -2.56%
# 1828  Aug 11, 2014   39.0   38.0   39.0   38.0  891.59K    2.63%
#
# [1829 rows x 7 columns]

# %%
df.isnull().sum()
# Out:
# Date        0
# Close       0
# Open        0
# High        0
# Low         0
# Vol.        0
# Change %    0
# dtype: int64

# %%
stockprices = df.sort_values('Date')

# %%
def calculate_rmse(y_actual, y_predict):
    """
    Calculate the Root Mean Squared Error (RMSE)
    """
    rmse = np.sqrt(np.mean((y_actual - y_predict)**2))
    return rmse

# %%
def calculate_mape(y_actual, y_predict):
    """
    Calculate the Mean Absolute Percentage Error (MAPE)
    """
    y_predict, y_actual = np.array(y_predict), np.array(y_actual)
    mape = np.mean(np.abs((y_actual - y_predict) / y_actual)) * 100
    return mape

# %%
def extract_seqX_outcomeY(data, N, offset_value):
    """
    Split time-series into training sequence X and outcome value Y
    Args:
    data - dataset
    N - window size, e.g., 60 for 60 days
    offset_value - position to start the split
    """
    training_Sequence_X = []
    output_value_y = []

    for i in range(offset_value, len(data)):
        training_Sequence_X.append(data[i-N:i])
        output_value_y.append(data[i])

    return np.array(training_Sequence_X), np.array(output_value_y)

# %%
test_ratio = 0.2
training_ratio = 0.8

training_size = int(training_ratio * len(stockprices))
testing_size = int(test_ratio * len(stockprices))

print('training_size: ' + str(training_size))
print('testing_size: ' + str(testing_size))

train = stockprices[:training_size][['Date', 'Close']]
test = stockprices[1464:][['Date', 'Close']]

print(train.shape)
print(test.shape)
# Out:
# training_size: 1463
# testing_size: 365
# (1463, 2)
# (365, 2)

# %%
stockprices = stockprices.set_index('Date')

# %%
def plotting_stock_trend(var, current_title, stockprices=stockprices):
    ax = stockprices[['Close', var, '200day']].plot(figsize = (20, 10))
    plt.grid(False)
    plt.title(current_title)
    plt.axis('tight')
    plt.ylabel('Stock Price ($)')

def calculate_perform_metrics(var):
    ### Root mean squared error
    rmse = calculate_rmse(np.array(stockprices[training_size:]['Close']), np.array(stockprices[training_size:][var]))
    ### Mean absolute percentage error
    mape = calculate_mape(np.array(stockprices[training_size:]['Close']), np.array(stockprices[training_size:][var]))

    return rmse, mape

# %%
window_size = 50

# %%
window_variable = str(window_size) + ' day'

stockprices[window_variable] = stockprices['Close'].rolling(window_size).mean()
### for reference, include 200 day simple moving average
stockprices['200day'] = stockprices['Close'].rolling(200).mean()

### plotting and performance metrics for simple moving average model
plotting_stock_trend(var = window_variable, current_title = 'Simple Moving Averages')
rmse_sma, mape_sma = calculate_perform_metrics(var=window_variable)
print('RMSE:', rmse_sma)
print('MAPE %:', mape_sma)
# Out:
# RMSE: 51.48152736228038
# MAPE %: 34.44310144175638

# %%
### Exponential MA
window_ema_variable = str(window_size) + ' day' + ' EMA'
# Calculate the exponentially weighted moving average for the Nth day
stockprices[window_ema_variable] = stockprices['Close'].ewm(span = window_size, adjust = False).mean()
stockprices['200day'] = stockprices['Close'].rolling(200).mean()

### plotting and performance metrics for exponential moving average model
plotting_stock_trend(var = window_ema_variable, current_title = 'Exponential Moving Averages')
rmse_ema, mape_ema = calculate_perform_metrics(var = window_ema_variable)
print('RMSE:', rmse_ema)
print('MAPE %:', mape_ema)
# Out:
# RMSE: 50.78540206928978
# MAPE %: 34.220403398186335

# %%
layer_units = 100
optimizer = 'adam'
current_epochs = 500
current_batch_size = 100

current_LSTM_parameters = {'units': layer_units,
                           'optimizer': optimizer,
                           'batch_size': current_batch_size,
                           'epochs': current_epochs
                          }
    
## use the past N stock prices for training to predict the N+1th closing price

# scale 
scaler = StandardScaler()
scaled_data = scaler.fit_transform(stockprices[['Close']])
scaled_data_train = scaled_data[:train.shape[0]]
   
X_train, y_train = extract_seqX_outcomeY(scaled_data_train, window_size, window_size)

### build a LSTM model
def Run_LSTM(X_train, layer_units = 50):
    inp = Input(shape=(X_train.shape[1], 1))

    x = LSTM(units=layer_units, return_sequences=True)(inp)
    x = LSTM(units=layer_units)(x)
    out = Dense(1, activation='linear')(x)
    model = Model(inp, out)

    # Compile the LSTM model
    model.compile(loss = 'mean_squared_error', optimizer = 'adam')

    return model
    
model = Run_LSTM(X_train, layer_units = layer_units)

history = model.fit(X_train, y_train, epochs=current_epochs, batch_size=current_batch_size, verbose=1, validation_split=0.1, shuffle=True)

# predicting stock price using past window_size stock prices
def preprocess_test_data(data=stockprices, scaler=scaler, window_size=window_size, test=test): 
    raw = data['Close'][len(data) - len(test) - window_size:].values
    raw = raw.reshape(-1,1)
    raw = scaler.transform(raw)

    X_test = []
    for i in range(window_size, raw.shape[0]):
        X_test.append(raw[i-window_size:i, 0])
        
    X_test = np.array(X_test)

    X_test = np.reshape(X_test, (X_test.shape[0], X_test.shape[1], 1))
    return X_test
    
X_test = preprocess_test_data()

predicted_price_ = model.predict(X_test)
predicted_price = scaler.inverse_transform(predicted_price_)

# plot predicted price vs actual closing price
test['Predictions_lstm'] = predicted_price

# Evaluate performance
rmse_lstm = calculate_rmse(np.array(test['Close']), np.array(test['Predictions_lstm']))
mape_lstm = calculate_mape(np.array(test['Close']), np.array(test['Predictions_lstm']))


### Plot preidiction and true trends
def plotting_stock_trend_lstm(train, test):        
    fig = plt.figure(figsize = (20,10))
    plt.plot(train['Date'], train['Close'], label = 'Train Closing Price')
    plt.plot(test['Date'], test['Close'], label = 'Test Closing Price')
    plt.plot(test['Date'], test['Predictions_lstm'], label = 'Predicted Closing Price')
    plt.title('LSTM Model')
    plt.xlabel('Date')
    plt.ylabel('Stock Price ($)')
    plt.legend(loc="upper left")

plotting_stock_trend_lstm(train, test)

print("RMSE:",rmse_lstm)
print("MAPE %:",mape_lstm)
# Out:
# 13/13 [==============================] - 3s 203ms/step - loss: 0.0156 - val_loss: 0.6450
# Epoch 178/500
# 13/13 [==============================] - 3s 215ms/step - loss: 0.0171 - val_loss: 0.6382
# Epoch 179/500
# 13/13 [==============================] - 3s 205ms/step - loss: 0.0157 - val_loss: 0.6048
# Epoch 180/500
# 13/13 [==============================] - 3s 199ms/step - loss: 0.0157 - val_loss: 0.6091
# Epoch 181/500
# 13/13 [==============================] - 3s 206ms/step - loss: 0.0114 - val_loss: 0.5973
# Epoch 182/500
# 13/13 [==============================] - 3s 205ms/step - loss: 0.0093 - val_loss: 0.6057
# Epoch 183/500
# 13/13 [==============================] - 3s 200ms/step - loss: 0.0088 - val_loss: 0.6528
# Epoch 184/500
# 13/13 [==============================] - 3s 202ms/step - loss: 0.0092 - val_loss: 0.6297
# Epoch 185/500
# 13/13 [==============================] - 3s 210ms/step - loss: 0.0085 - val_loss: 0.6078
# Epoch 186/500
# 13/13 [==============================] - 3s 212ms/step - loss: 0.0096 - val_loss: 0.5948
# Epoch 187/500
# 13/13 [==============================] - 3s 203ms/step - loss: 0.0153 - val_loss: 0.6509
# Epoch 188/500
# 13/13 [==============================] - 3s 196ms/step - loss: 0.0291 - val_loss: 0.5607
# Epoch 189/500
# 13/13 [==============================] - 3s 207ms/step - loss: 0.0310 - val_loss: 0.6199
# Epoch 190/500
# 13/13 [==============================] - 3s 204ms/step - loss: 0.0319 - val_loss: 0.5852
# Epoch 191/500
# 13/13 [==============================] - 3s 199ms/step - loss: 0.0244 - val_loss: 0.6208
# Epoch 192/500
# 13/13 [==============================] - 3s 197ms/step - loss: 0.0183 - val_loss: 0.6071
# Epoch 193/500
# 13/13 [==============================] - 3s 199ms/step - loss: 0.0152 - val_loss: 0.6163
# Epoch 194/500
# 13/13 [==============================] - 3s 196ms/step - loss: 0.0144 - val_loss: 0.5835
# Epoch 195/500
# 13/13 [==============================] - 3s 196ms/step - loss: 0.0159 - val_loss: 0.6336
# Epoch 196/500
# 13/13 [==============================] - 3s 206ms/step - loss: 0.0135 - val_loss: 0.6408
# Epoch 197/500
# 13/13 [==============================] - 3s 207ms/step - loss: 0.0117 - val_loss: 0.5998
# Epoch 198/500
# 13/13 [==============================] - 3s 196ms/step - loss: 0.0094 - val_loss: 0.5864
# Epoch 199/500
# 13/13 [==============================] - 3s 196ms/step - loss: 0.0077 - val_loss: 0.6147
# Epoch 200/500
# 13/13 [==============================] - 3s 206ms/step - loss: 0.0067 - val_loss: 0.6398
# Epoch 201/500
# 13/13 [==============================] - 3s 204ms/step - loss: 0.0063 - val_loss: 0.6287
# Epoch 202/500
# 13/13 [==============================] - 3s 205ms/step - loss: 0.0059 - val_loss: 0.6114
# Epoch 203/500
# 13/13 [==============================] - 3s 200ms/step - loss: 0.0058 - val_loss: 0.6143
# Epoch 204/500
# 13/13 [==============================] - 3s 204ms/step - loss: 0.0052 - val_loss: 0.6386
# Epoch 205/500
# 13/13 [==============================] - 3s 207ms/step - loss: 0.0050 - val_loss: 0.6074
# Epoch 206/500
# 13/13 [==============================] - 3s 201ms/step - loss: 0.0048 - val_loss: 0.6334
# Epoch 207/500
# 13/13 [==============================] - 3s 201ms/step - loss: 0.0045 - val_loss: 0.6395
# Epoch 208/500
# 13/13 [==============================] - 3s 203ms/step - loss: 0.0042 - val_loss: 0.6318
# Epoch 209/500
# 13/13 [==============================] - 3s 201ms/step - loss: 0.0042 - val_loss: 0.6310
# Epoch 210/500
# 13/13 [==============================] - 3s 211ms/step - loss: 0.0045 - val_loss: 0.6118
# Epoch 211/500
# 13/13 [==============================] - 3s 216ms/step - loss: 0.0045 - val_loss: 0.6289
# Epoch 212/500
# 13/13 [==============================] - 3s 211ms/step - loss: 0.0044 - val_loss: 0.6220
# Epoch 213/500
# 13/13 [==============================] - 3s 198ms/step - loss: 0.0048 - val_loss: 0.6417
# Epoch 214/500
# 13/13 [==============================] - 3s 205ms/step - loss: 0.0043 - val_loss: 0.6403
# Epoch 215/500
# 13/13 [==============================] - 3s 200ms/step - loss: 0.0042 - val_loss: 0.6302
# Epoch 216/500
# 13/13 [==============================] - 3s 206ms/step - loss: 0.0039 - val_loss: 0.6294
# Epoch 217/500
# 13/13 [==============================] - 3s 206ms/step - loss: 0.0038 - val_loss: 0.6280
# Epoch 218/500
# 13/13 [==============================] - 3s 218ms/step - loss: 0.0037 - val_loss: 0.6365
# Epoch 219/500
# 13/13 [==============================] - 3s 204ms/step - loss: 0.0035 - val_loss: 0.6295
# Epoch 220/500
# 13/13 [==============================] - 3s 199ms/step - loss: 0.0035 - val_loss: 0.6329
# Epoch 221/500
# 13/13 [==============================] - 3s 201ms/step - loss: 0.0033 - val_loss: 0.6385
# Epoch 222/500
# 13/13 [==============================] - 3s 215ms/step - loss: 0.0031 - val_loss: 0.6276
# Epoch 223/500
# 13/13 [==============================] - 3s 205ms/step - loss: 0.0030 - val_loss: 0.6389
# Epoch 224/500
# 13/13 [==============================] - 3s 199ms/step - loss: 0.0030 - val_loss: 0.6262
# Epoch 225/500
# 13/13 [==============================] - 3s 196ms/step - loss: 0.0029 - val_loss: 0.6409
# Epoch 226/500
# 13/13 [==============================] - 3s 197ms/step - loss: 0.0028 - val_loss: 0.6377
# Epoch 227/500
# 13/13 [==============================] - 3s 203ms/step - loss: 0.0028 - val_loss: 0.6466
# Epoch 228/500
# 13/13 [==============================] - 3s 205ms/step - loss: 0.0028 - val_loss: 0.6348
# Epoch 229/500
# 13/13 [==============================] - 3s 197ms/step - loss: 0.0024 - val_loss: 0.6372
# Epoch 230/500
# 13/13 [==============================] - 3s 207ms/step - loss: 0.0023 - val_loss: 0.6341
# Epoch 231/500
# 13/13 [==============================] - 3s 207ms/step - loss: 0.0025 - val_loss: 0.6232
# Epoch 232/500
# 13/13 [==============================] - 3s 210ms/step - loss: 0.0026 - val_loss: 0.6490
# Epoch 233/500
# 13/13 [==============================] - 3s 208ms/step - loss: 0.0027 - val_loss: 0.6351
# Epoch 234/500
# 13/13 [==============================] - 3s 214ms/step - loss: 0.0028 - val_loss: 0.6395
# Epoch 235/500
# 13/13 [==============================] - 3s 206ms/step - loss: 0.0032 - val_loss: 0.6456
# Epoch 236/500
# 13/13 [==============================] - 3s 198ms/step - loss: 0.0034 - val_loss: 0.6309
# Epoch 237/500
# 13/13 [==============================] - 3s 203ms/step - loss: 0.0031 - val_loss: 0.6544
# Epoch 238/500
# 13/13 [==============================] - 3s 207ms/step - loss: 0.0030 - val_loss: 0.6391
# Epoch 239/500
# 13/13 [==============================] - 3s 205ms/step - loss: 0.0031 - val_loss: 0.6360
# Epoch 240/500
# 13/13 [==============================] - 3s 206ms/step - loss: 0.0028 - val_loss: 0.6386
# Epoch 241/500
# 13/13 [==============================] - 3s 207ms/step - loss: 0.0040 - val_loss: 0.6326
# Epoch 242/500
# 13/13 [==============================] - 3s 206ms/step - loss: 0.0046 - val_loss: 0.6440
# Epoch 243/500
# 13/13 [==============================] - 3s 213ms/step - loss: 0.0061 - val_loss: 0.6310
# Epoch 244/500
# 13/13 [==============================] - 3s 206ms/step - loss: 0.0096 - val_loss: 0.6257
# Epoch 245/500
# 13/13 [==============================] - 3s 205ms/step - loss: 0.0169 - val_loss: 0.6173
# Epoch 246/500
# 13/13 [==============================] - 3s 205ms/step - loss: 0.0327 - val_loss: 0.6548
# Epoch 247/500
# 13/13 [==============================] - 3s 211ms/step - loss: 0.0373 - val_loss: 0.6128
# Epoch 248/500
# 13/13 [==============================] - 3s 201ms/step - loss: 0.0386 - val_loss: 0.5648
# Epoch 249/500
# 13/13 [==============================] - 3s 210ms/step - loss: 0.0277 - val_loss: 0.5718
# Epoch 250/500
# 13/13 [==============================] - 3s 203ms/step - loss: 0.0225 - val_loss: 0.5701
# Epoch 251/500
# 13/13 [==============================] - 3s 205ms/step - loss: 0.0170 - val_loss: 0.6164
# Epoch 252/500
# 13/13 [==============================] - 3s 214ms/step - loss: 0.0132 - val_loss: 0.6660
# Epoch 253/500
# 13/13 [==============================] - 3s 207ms/step - loss: 0.0152 - val_loss: 0.5846
# Epoch 254/500
# 13/13 [==============================] - 3s 199ms/step - loss: 0.0135 - val_loss: 0.5969
# Epoch 255/500
# 13/13 [==============================] - 3s 200ms/step - loss: 0.0116 - val_loss: 0.6327
# Epoch 256/500
# 13/13 [==============================] - 3s 198ms/step - loss: 0.0112 - val_loss: 0.6009
# Epoch 257/500
# 13/13 [==============================] - 3s 196ms/step - loss: 0.0080 - val_loss: 0.6010
# Epoch 258/500
# 13/13 [==============================] - 3s 202ms/step - loss: 0.0064 - val_loss: 0.5772
# Epoch 259/500
# 13/13 [==============================] - 3s 213ms/step - loss: 0.0046 - val_loss: 0.6027
# Epoch 260/500
# 13/13 [==============================] - 3s 200ms/step - loss: 0.0036 - val_loss: 0.5862
# Epoch 261/500
# 13/13 [==============================] - 3s 208ms/step - loss: 0.0028 - val_loss: 0.5857
# Epoch 262/500
# 13/13 [==============================] - 3s 214ms/step - loss: 0.0027 - val_loss: 0.5972
# Epoch 263/500
# 13/13 [==============================] - 3s 203ms/step - loss: 0.0024 - val_loss: 0.5922
# Epoch 264/500
# 13/13 [==============================] - 3s 200ms/step - loss: 0.0021 - val_loss: 0.5923
# Epoch 265/500
# 13/13 [==============================] - 3s 207ms/step - loss: 0.0019 - val_loss: 0.6040
# Epoch 266/500
# 13/13 [==============================] - 3s 208ms/step - loss: 0.0017 - val_loss: 0.5991
# Epoch 267/500
# 13/13 [==============================] - 3s 213ms/step - loss: 0.0017 - val_loss: 0.5990
# Epoch 268/500
# 13/13 [==============================] - 3s 207ms/step - loss: 0.0017 - val_loss: 0.6045
# Epoch 269/500
# 13/13 [==============================] - 3s 195ms/step - loss: 0.0017 - val_loss: 0.6051
# Epoch 270/500
# 13/13 [==============================] - 3s 197ms/step - loss: 0.0016 - val_loss: 0.5983
# Epoch 271/500
# 13/13 [==============================] - 3s 211ms/step - loss: 0.0015 - val_loss: 0.6032
# Epoch 272/500
# 13/13 [==============================] - 3s 211ms/step - loss: 0.0014 - val_loss: 0.6066
# Epoch 273/500
# 13/13 [==============================] - 3s 202ms/step - loss: 0.0014 - val_loss: 0.6027
# Epoch 274/500
# 13/13 [==============================] - 3s 214ms/step - loss: 0.0013 - val_loss: 0.6045
# Epoch 275/500
# 13/13 [==============================] - 3s 210ms/step - loss: 0.0012 - val_loss: 0.6073
# Epoch 276/500
# 13/13 [==============================] - 3s 207ms/step - loss: 0.0014 - val_loss: 0.6005
# Epoch 277/500
# 13/13 [==============================] - 3s 211ms/step - loss: 0.0014 - val_loss: 0.6077
# Epoch 278/500
# 13/13 [==============================] - 3s 211ms/step - loss: 0.0013 - val_loss: 0.6088
# Epoch 279/500
# 13/13 [==============================] - 3s 208ms/step - loss: 0.0013 - val_loss: 0.6103
# Epoch 280/500
# 13/13 [==============================] - 3s 209ms/step - loss: 0.0013 - val_loss: 0.6110
# Epoch 281/500
# 13/13 [==============================] - 3s 213ms/step - loss: 0.0013 - val_loss: 0.6114
# Epoch 282/500
# 13/13 [==============================] - 3s 211ms/step - loss: 0.0012 - val_loss: 0.6087
# Epoch 283/500
# 13/13 [==============================] - 3s 197ms/step - loss: 0.0013 - val_loss: 0.6088
# Epoch 284/500
# 13/13 [==============================] - 3s 197ms/step - loss: 0.0013 - val_loss: 0.6129
# Epoch 285/500
# 13/13 [==============================] - 3s 204ms/step - loss: 0.0013 - val_loss: 0.6122
# Epoch 286/500
# 13/13 [==============================] - 3s 196ms/step - loss: 0.0012 - val_loss: 0.6165
# Epoch 287/500
# 13/13 [==============================] - 3s 207ms/step - loss: 0.0012 - val_loss: 0.6172
# Epoch 288/500
# 13/13 [==============================] - 3s 213ms/step - loss: 0.0012 - val_loss: 0.6067
# Epoch 289/500
# 13/13 [==============================] - 3s 209ms/step - loss: 0.0014 - val_loss: 0.6116
# Epoch 290/500
# 13/13 [==============================] - 3s 203ms/step - loss: 0.0015 - val_loss: 0.6088
# Epoch 291/500
# 13/13 [==============================] - 3s 197ms/step - loss: 0.0015 - val_loss: 0.6132
# Epoch 292/500
# 13/13 [==============================] - 3s 209ms/step - loss: 0.0015 - val_loss: 0.6133
# Epoch 293/500
# 13/13 [==============================] - 3s 205ms/step - loss: 0.0013 - val_loss: 0.6230
# Epoch 294/500
# 13/13 [==============================] - 3s 208ms/step - loss: 0.0011 - val_loss: 0.6186
# Epoch 295/500
# 13/13 [==============================] - 3s 214ms/step - loss: 0.0010 - val_loss: 0.6133
# Epoch 296/500
# 13/13 [==============================] - 3s 207ms/step - loss: 9.8775e-04 - val_loss: 0.6070
# Epoch 297/500
# 13/13 [==============================] - 3s 199ms/step - loss: 0.0011 - val_loss: 0.6237
# Epoch 298/500
# 13/13 [==============================] - 3s 210ms/step - loss: 0.0011 - val_loss: 0.6077
# Epoch 299/500
# 13/13 [==============================] - 3s 195ms/step - loss: 0.0012 - val_loss: 0.6208
# Epoch 300/500
# 13/13 [==============================] - 3s 198ms/step - loss: 0.0011 - val_loss: 0.6150
# Epoch 301/500
# 13/13 [==============================] - 3s 204ms/step - loss: 0.0012 - val_loss: 0.6127
# Epoch 302/500
# 13/13 [==============================] - 3s 208ms/step - loss: 0.0011 - val_loss: 0.6154
# Epoch 303/500
# 13/13 [==============================] - 3s 207ms/step - loss: 0.0013 - val_loss: 0.6193
# Epoch 304/500
# 13/13 [==============================] - 3s 199ms/step - loss: 0.0013 - val_loss: 0.6229
# Epoch 305/500
# 13/13 [==============================] - 3s 197ms/step - loss: 0.0013 - val_loss: 0.6293
# Epoch 306/500
# 13/13 [==============================] - 3s 203ms/step - loss: 0.0016 - val_loss: 0.6289
# Epoch 307/500
# 13/13 [==============================] - 3s 199ms/step - loss: 0.0015 - val_loss: 0.6155
# Epoch 308/500
# 13/13 [==============================] - 3s 208ms/step - loss: 0.0013 - val_loss: 0.6189
# Epoch 309/500
# 13/13 [==============================] - 3s 208ms/step - loss: 0.0014 - val_loss: 0.6254
# Epoch 310/500
# 13/13 [==============================] - 3s 204ms/step - loss: 0.0013 - val_loss: 0.6103
# Epoch 311/500
# 13/13 [==============================] - 3s 212ms/step - loss: 0.0013 - val_loss: 0.6071
# Epoch 312/500
# 13/13 [==============================] - 3s 207ms/step - loss: 0.0013 - val_loss: 0.6126
# Epoch 313/500
# 13/13 [==============================] - 3s 204ms/step - loss: 0.0013 - val_loss: 0.6156
# Epoch 314/500
# 13/13 [==============================] - 3s 213ms/step - loss: 0.0014 - val_loss: 0.6154
# Epoch 315/500
# 13/13 [==============================] - 3s 210ms/step - loss: 0.0014 - val_loss: 0.6260
# Epoch 316/500
# 13/13 [==============================] - 3s 199ms/step - loss: 0.0015 - val_loss: 0.6216
# Epoch 317/500
# 13/13 [==============================] - 3s 201ms/step - loss: 0.0016 - val_loss: 0.6219
# Epoch 318/500
# 13/13 [==============================] - 3s 200ms/step - loss: 0.0015 - val_loss: 0.6216
# Epoch 319/500
# 13/13 [==============================] - 3s 202ms/step - loss: 0.0014 - val_loss: 0.6253
# Epoch 320/500
# 13/13 [==============================] - 3s 208ms/step - loss: 0.0013 - val_loss: 0.6185
# Epoch 321/500
# 13/13 [==============================] - 3s 211ms/step - loss: 0.0012 - val_loss: 0.6373
# Epoch 322/500
# 13/13 [==============================] - 3s 207ms/step - loss: 0.0013 - val_loss: 0.6294
# Epoch 323/500
# 13/13 [==============================] - 3s 212ms/step - loss: 0.0013 - val_loss: 0.6381
# Epoch 324/500
# 13/13 [==============================] - 3s 197ms/step - loss: 0.0013 - val_loss: 0.6121
# Epoch 325/500
# 13/13 [==============================] - 3s 210ms/step - loss: 0.0012 - val_loss: 0.6221
# Epoch 326/500
# 13/13 [==============================] - 3s 199ms/step - loss: 0.0012 - val_loss: 0.6299
# Epoch 327/500
# 13/13 [==============================] - 3s 199ms/step - loss: 0.0014 - val_loss: 0.6178
# Epoch 328/500
# 13/13 [==============================] - 3s 198ms/step - loss: 0.0016 - val_loss: 0.6185
# Epoch 329/500
# 13/13 [==============================] - 3s 211ms/step - loss: 0.0014 - val_loss: 0.6295
# Epoch 330/500
# 13/13 [==============================] - 3s 197ms/step - loss: 0.0015 - val_loss: 0.6235
# Epoch 331/500
# 13/13 [==============================] - 3s 208ms/step - loss: 0.0017 - val_loss: 0.6107
# Epoch 332/500
# 13/13 [==============================] - 3s 206ms/step - loss: 0.0016 - val_loss: 0.6236
# Epoch 333/500
# 13/13 [==============================] - 3s 197ms/step - loss: 0.0017 - val_loss: 0.6189
# Epoch 334/500
# 13/13 [==============================] - 3s 201ms/step - loss: 0.0019 - val_loss: 0.6294
# Epoch 335/500
# 13/13 [==============================] - 3s 209ms/step - loss: 0.0018 - val_loss: 0.6192
# Epoch 336/500
# 13/13 [==============================] - 3s 196ms/step - loss: 0.0021 - val_loss: 0.6201
# Epoch 337/500
# 13/13 [==============================] - 3s 198ms/step - loss: 0.0020 - val_loss: 0.6182
# Epoch 338/500
# 13/13 [==============================] - 3s 206ms/step - loss: 0.0023 - val_loss: 0.6245
# Epoch 339/500
# 13/13 [==============================] - 3s 204ms/step - loss: 0.0024 - val_loss: 0.6328
# Epoch 340/500
# 13/13 [==============================] - 3s 210ms/step - loss: 0.0024 - val_loss: 0.6146
# Epoch 341/500
# 13/13 [==============================] - 3s 210ms/step - loss: 0.0024 - val_loss: 0.6425
# Epoch 342/500
# 13/13 [==============================] - 3s 203ms/step - loss: 0.0032 - val_loss: 0.6278
# Epoch 343/500
# 13/13 [==============================] - 3s 198ms/step - loss: 0.0040 - val_loss: 0.6368
# Epoch 344/500
# 13/13 [==============================] - 3s 204ms/step - loss: 0.0040 - val_loss: 0.6537
# Epoch 345/500
# 13/13 [==============================] - 3s 199ms/step - loss: 0.0039 - val_loss: 0.6305
# Epoch 346/500
# 13/13 [==============================] - 3s 213ms/step - loss: 0.0051 - val_loss: 0.6087
# Epoch 347/500
# 13/13 [==============================] - 3s 207ms/step - loss: 0.0059 - val_loss: 0.6028
# Epoch 348/500
# 13/13 [==============================] - 3s 199ms/step - loss: 0.0046 - val_loss: 0.6327
# Epoch 349/500
# 13/13 [==============================] - 3s 200ms/step - loss: 0.0042 - val_loss: 0.6538
# Epoch 350/500
# 13/13 [==============================] - 3s 200ms/step - loss: 0.0041 - val_loss: 0.6388
# Epoch 351/500
# 13/13 [==============================] - 3s 209ms/step - loss: 0.0039 - val_loss: 0.6206
# Epoch 352/500
# 13/13 [==============================] - 3s 199ms/step - loss: 0.0046 - val_loss: 0.5956
# Epoch 353/500
# 13/13 [==============================] - 3s 199ms/step - loss: 0.0056 - val_loss: 0.6120
# Epoch 354/500
# 13/13 [==============================] - 3s 198ms/step - loss: 0.0046 - val_loss: 0.6149
# Epoch 355/500
# 13/13 [==============================] - 3s 206ms/step - loss: 0.0057 - val_loss: 0.6353
# Epoch 356/500
# 13/13 [==============================] - 3s 195ms/step - loss: 0.0096 - val_loss: 0.6369
# Epoch 357/500
# 13/13 [==============================] - 3s 204ms/step - loss: 0.0169 - val_loss: 0.5954
# Epoch 358/500
# 13/13 [==============================] - 3s 202ms/step - loss: 0.0408 - val_loss: 0.5471
# Epoch 359/500
# 13/13 [==============================] - 3s 207ms/step - loss: 0.1071 - val_loss: 0.6230
# Epoch 360/500
# 13/13 [==============================] - 3s 207ms/step - loss: 0.1419 - val_loss: 0.5626
# Epoch 361/500
# 13/13 [==============================] - 3s 195ms/step - loss: 0.1375 - val_loss: 0.4982
# Epoch 362/500
# 13/13 [==============================] - 3s 196ms/step - loss: 0.1461 - val_loss: 0.5361
# Epoch 363/500
# 13/13 [==============================] - 3s 198ms/step - loss: 0.1157 - val_loss: 0.5115
# Epoch 364/500
# 13/13 [==============================] - 3s 204ms/step - loss: 0.0985 - val_loss: 0.6184
# Epoch 365/500
# 13/13 [==============================] - 3s 199ms/step - loss: 0.0915 - val_loss: 0.5373
# Epoch 366/500
# 13/13 [==============================] - 3s 206ms/step - loss: 0.0663 - val_loss: 0.5860
# Epoch 367/500
# 13/13 [==============================] - 3s 212ms/step - loss: 0.0495 - val_loss: 0.5758
# Epoch 368/500
# 13/13 [==============================] - 3s 198ms/step - loss: 0.0316 - val_loss: 0.6018
# Epoch 369/500
# 13/13 [==============================] - 3s 196ms/step - loss: 0.0222 - val_loss: 0.5712
# Epoch 370/500
# 13/13 [==============================] - 3s 199ms/step - loss: 0.0175 - val_loss: 0.5698
# Epoch 371/500
# 13/13 [==============================] - 3s 210ms/step - loss: 0.0126 - val_loss: 0.5867
# Epoch 372/500
# 13/13 [==============================] - 3s 209ms/step - loss: 0.0098 - val_loss: 0.5600
# Epoch 373/500
# 13/13 [==============================] - 3s 213ms/step - loss: 0.0082 - val_loss: 0.5801
# Epoch 374/500
# 13/13 [==============================] - 3s 208ms/step - loss: 0.0060 - val_loss: 0.5875
# Epoch 375/500
# 13/13 [==============================] - 3s 208ms/step - loss: 0.0052 - val_loss: 0.5748
# Epoch 376/500
# 13/13 [==============================] - 3s 213ms/step - loss: 0.0045 - val_loss: 0.5877
# Epoch 377/500
# 13/13 [==============================] - 3s 204ms/step - loss: 0.0041 - val_loss: 0.5777
# Epoch 378/500
# 13/13 [==============================] - 3s 198ms/step - loss: 0.